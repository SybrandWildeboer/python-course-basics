# %% [markdown]
# # Live exercise: about me
#
# Build a small program that works out somebody's age and prints a sentence
# about them.
#
# Work in **small steps**, and run each cell as you go. Do not write the whole
# thing and hope.
#
# ## Step 1
#
# The notebook version starts with the values written down, rather than asking
# for them. Change them to your own.

# %%
name = "Sam"
birth_year = 1985
CURRENT_YEAR = 2026

# %% [markdown]
# ## Step 2
#
# Print the name back, to check it is there.

# %%
# TODO: print the name

# %% [markdown]
# ## Step 3
#
# Work out the age, and store it in a variable called `age`.
#
# ("About", because we do not know whether their birthday has happened yet
# this year. Small honesty, worth having.)

# %%
# TODO: age = ...

# %% [markdown]
# ## Step 4
#
# Print **one sentence** containing both the name and the age, using an
# f-string.

# %%
# TODO: print one sentence

# %% [markdown]
# ## Step 5, if that worked
#
# * print how old they will be in 2030
# * print the name in capitals (hint: `.upper()`)
# * print the age in ten years, without creating a new variable

# %%
# TODO: the extras

# %% [markdown]
# ## Then: the script version
#
# Open `sessions/session-01/exercises/about_me.py` and build the same thing as
# a script that **asks** for the name and birth year with `input()`.
#
# Run it from the terminal:
#
# ```
# python3 sessions/session-01/exercises/about_me.py
# ```
#
# That is the difference worth feeling: the notebook is for working things out,
# the script is for handing somebody a thing that runs.
