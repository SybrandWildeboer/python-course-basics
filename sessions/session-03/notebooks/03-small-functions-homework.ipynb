# %% [markdown]
# # Homework: four small functions
#
# Each one **returns** its answer. None of them print.
#
# | Function | Given | Returns |
# |---|---|---|
# | `is_even(n)` | `4` | `True` |
# | `celsius_to_fahrenheit(c)` | `21.5` | `70.7` |
# | `initials(full_name)` | `"Sam Kelly"` | `"S.K."` |
# | `longest_word(sentence)` | `"a bc def"` | `"def"` |
#
# Requirements:
#
# * a one-line docstring on each, saying what it returns
# * at least two `assert` checks each
# * include the awkward cases: what should `is_even(0)` say? What does
#   `longest_word("")` do?
#
# **You will need to look something up.** `longest_word` needs a way to chop a
# sentence into words. Search for "python split string into words". That is
# part of the exercise, not cheating: looking things up as you need them is
# what programming actually is.

# %%
# TODO: def is_even(n):

# %%
# TODO: def celsius_to_fahrenheit(c):

# %%
# TODO: def initials(full_name):

# %%
# TODO: def longest_word(sentence):

# %% [markdown]
# ## Your checks
#
# At least two per function, and include the awkward cases.

# %%
# TODO: assert lines

# %% [markdown]
# ## The other homework task
#
# Task 2 is a menu program, and it lives in
# `sessions/session-03/homework/menu.py`.
#
# It stays a **script**, because it asks the user to pick an option and keeps
# asking until they quit. Interactive programs want to be scripts.
#
# It does show you one genuinely useful thing though: how a script **imports**
# functions from another file, so the same four functions serve both.
#
# ## Before you finish
#
# Search your work for `print` inside a function definition. If one of the four
# above prints instead of returning, the menu program cannot use it: it can
# show you the answer but it cannot pass it on.
