# %% [markdown]
# # Live exercise: rebuild your statistics as functions
#
# Take the four calculations from last week and turn each one into a function
# that **takes** a list and **returns** a number.
#
# None of the four should print anything.
#
# ```
# def total(numbers)      ->  the sum
# def average(numbers)    ->  the mean
# def highest(numbers)    ->  the biggest value
# def lowest(numbers)     ->  the smallest value
# ```
#
# Still no `sum()`, `max()` or `min()`. Loops, as before.

# %%
NUMBERS = [12, 7, 41, 3, 28, 19, 7, 55, 2, 33]
SECOND_LIST = [4, 8, 15, 16, 23, 42]

# %% [markdown]
# ## The four functions
#
# Give each one a one-line docstring.

# %%
# TODO: def total(numbers):

# %%
# TODO: def average(numbers):
#       Once total() works, write this one so it CALLS total().
#       That moment is the point of the whole exercise.

# %%
# TODO: def highest(numbers):

# %%
# TODO: def lowest(numbers):

# %% [markdown]
# ## Check them
#
# Uncomment these once your four functions exist. Silence means they pass.
#
# Notice what the third and fourth lines are testing: the awkward case from
# last week, pinned down so it can never come back.

# %%
# assert total([1, 2, 3]) == 6
# assert average([2, 4]) == 3
# assert highest([-5, -2, -9]) == -2
# assert lowest([-5, -2, -9]) == -9
# assert highest([7]) == 7
# print("all checks passed")

# %% [markdown]
# ## Now use them
#
# Print one summary line for `NUMBERS` that uses all four functions.

# %%
# TODO: a summary line for NUMBERS

# %% [markdown]
# ## And now the part that sells functions
#
# Do the same for `SECOND_LIST`, **without copying any of the logic**.

# %%
# TODO: a summary line for SECOND_LIST

# %% [markdown]
# That second summary should have cost you one line.
#
# In last week's version it would have meant copying forty lines and renaming
# every variable, and any bug would then exist in two places.
