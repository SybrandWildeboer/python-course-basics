# %% [markdown]
# # Live exercise: clean it, then chart it
#
# From the messy file to one labelled, saved chart that answers a question.
#
# Write the cleaning as a **function** that takes the messy frame and returns a
# clean one. Session 10 will call it.

# %%
import os
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

here = Path.cwd()
while not (here / "data" / "messy").exists() and here != here.parent:
    here = here.parent
os.chdir(here)

OUTPUT = Path("output")
OUTPUT.mkdir(exist_ok=True)

messy = pd.read_csv("data/messy/plays_messy.csv")
print(messy.shape)
messy.head(3)

# %% [markdown]
# ## 1. Look at the damage
#
# Print the shape and the missing-value counts. Then run
# `value_counts(dropna=False)` on every categorical column and note what is
# wrong with each.

# %%
# TODO

# %% [markdown]
# What did you find?
#
# * `genre`:
# * `device`:
# * `country`:
# * `minutes played `:
# * `played_at`:
#
# ## 2. Write the cleaning function
#
# One function, with a docstring that records the **decisions** you made, not
# just the steps.

# %%
def clean_plays(messy):
    """Return a cleaned copy of the messy listening log.

    Decisions made here:
      *
      *
    """
    df = messy.copy()

    # TODO: rename the column with the trailing space

    # TODO: strip whitespace, then settle on one capitalisation

    # TODO: make minutes_played numeric

    # TODO: parse the dates, per format

    # TODO: drop duplicate rows

    # TODO: decide what to do about each kind of missing value

    return df.reset_index(drop=True)

# %%
clean = clean_plays(messy)
clean.shape

# %% [markdown]
# ## 3. Check what your cleaning threw away

# %%
# TODO: print the before and after shapes, and the percentage lost

# %% [markdown]
# ## 4. Pick one question you can answer with a chart
#
# Write it here, as a sentence, before you plot anything.
#
# **My question:**
#
# ## 5. Build the chart
#
# `fig, ax`, a title that states the finding, both axes labelled, and saved as
# a PNG in `output/`.

# %%
# TODO: the chart

# %% [markdown]
# ## 6. Two sentences about what it shows
#
# And one about what it does **not** prove.
