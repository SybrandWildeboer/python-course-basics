# %% [markdown]
# # Homework: three charts and a findings file
#
# Three different questions, three different chart types, each saved as a PNG
# in `output/`.
#
# Every chart needs a title that states the finding and both axes labelled.
#
# Then write `findings.md` next to this notebook: two or three sentences per
# chart saying what it shows and what you are **not** entitled to conclude,
# plus one paragraph listing every cleaning decision you made and what it cost
# you.
#
# The prose is the harder half and it is the point.

# %%
import os
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

here = Path.cwd()
while not (here / "data" / "messy").exists() and here != here.parent:
    here = here.parent
os.chdir(here)

OUTPUT = Path("output")
OUTPUT.mkdir(exist_ok=True)


def clean_plays(messy):
    """Paste your cleaning function from the live exercise here."""
    # TODO
    return messy


plays = clean_plays(pd.read_csv("data/messy/plays_messy.csv"))
plays.shape

# %% [markdown]
# ## Chart 1
#
# **My question:**

# %%
# TODO

# %% [markdown]
# ## Chart 2
#
# A different chart type from chart 1.
#
# **My question:**

# %%
# TODO

# %% [markdown]
# ## Chart 3
#
# A third chart type.
#
# **My question:**

# %%
# TODO

# %% [markdown]
# ## Ideas, if nothing comes to mind
#
# * how listening changed month by month, and whether the two years differ
# * which devices get skipped most, and whether the gap is big enough to care
#   about
# * how play length is distributed, and whether the skips explain the short tail
# * whether artists formed more recently get played more
# * plays per country, and whether that says anything beyond "where the artists
#   in this collection happen to be from"
#
# That last one is worth thinking about: a chart can be accurate and still
# invite a wrong conclusion.
