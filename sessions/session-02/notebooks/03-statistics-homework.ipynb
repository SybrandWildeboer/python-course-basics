# %% [markdown]
# # Homework: statistics by hand
#
# Print the **total**, the **average**, the **highest** and the **lowest** of
# the list below.
#
# The catch: **no `sum()`, no `max()`, no `min()`**. Loops only. Those
# functions exist and you should use them in real life, but writing them
# yourself once is how you understand what a loop is actually for.
#
# Requirements:
#
# * the average prints to one decimal place
# * it still works if you change the list at the top
# * a comment above each of the four calculations saying what it does

# %%
numbers = [12, 7, 41, 3, 28, 19, 7, 55, 2, 33]

# %% [markdown]
# ## The total
#
# Set up a variable before the loop, update it inside, use it after.

# %%
# TODO: the total

# %% [markdown]
# ## The average
#
# The total divided by how many there are. `len(numbers)` counts the list.

# %%
# TODO: the average, to one decimal place

# %% [markdown]
# ## The highest
#
# **This is the interesting one.** What do you set your "highest so far"
# variable to *before* the loop starts?
#
# Zero is the obvious answer and it is wrong. Work out why by trying your
# version with `numbers = [-5, -2, -9]`.
#
# Sitting with that for ten minutes is worth more than being told the answer.

# %%
# TODO: the highest

# %% [markdown]
# ## The lowest

# %%
# TODO: the lowest

# %% [markdown]
# ## Check your work
#
# Run this cell when you are done. Silence means everything passed.

# %%
# Fill in your four answers here to check them.
# assert total == 207
# assert round(average, 1) == 20.7
# assert highest == 55
# assert lowest == 2
# print("all four correct")

# %% [markdown]
# ## Stretch, if you finish
#
# Also print how many of the numbers are above the average.

# %%
# TODO: the stretch goal

# %% [markdown]
# ## The other homework task
#
# Task 1 is the guessing game with a seven-attempt limit, and it lives in
# `sessions/session-02/homework/guessing_game_limited.py`.
#
# It stays a **script**, because it asks the player questions. A notebook is
# the wrong shape for anything interactive.
